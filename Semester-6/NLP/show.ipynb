# %%
# File name suggestion: show_lms_data.py

import pandas as pd

# Read the structured CSV
df = pd.read_csv("data/lms_structured.csv")

# Display the first 10 rows
print("✅ Showing first 10 rows of structured LMS data:\n")
print(df.head(100))
df.shape

# Optional: Display full DataFrame (be careful if very large)
# print(df)
# Out:
# ✅ Showing first 10 rows of structured LMS data:
#
#                     Phase                                           Question  \
# 0   Requirements Analysis  Q1: How were the initial requirements for the ...
# 1   Requirements Analysis  Q1: How were the initial requirements for the ...
# 2   Requirements Analysis  Q1: How were the initial requirements for the ...
# 3   Requirements Analysis  Q1: How were the initial requirements for the ...
# 4   Requirements Analysis  Q1: How were the initial requirements for the ...
# ..                    ...                                                ...
# 95  Design & Architecture  Q9: Is the system designed to support integrat...
# 96    Development Process  Q1: What programming languages or frameworks w...
# 97    Development Process  Q1: What programming languages or frameworks w...
# 98    Development Process  Q1: What programming languages or frameworks w...
# ...
