# %% [markdown]
# Digital Image process

# %%
print("hello")
# Out:
# hello

# %%
import numpy as np

# %%
# arr=np.array([1,2,3,4,[1,2,4,3]],dtype=object)
arr=np.array([[1,2,3,4]])
print(arr)
print(type(arr))
print(arr.ndim)
print("hello")
# Out:
# [[1 2 3 4]]
# <class 'numpy.ndarray'>
# 2
# hello
