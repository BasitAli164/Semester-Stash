# %% [markdown]
# # Assignment-3

# %% [markdown]
# Question:
#          Write a program then use some numpy functions in it.

# %%
import numpy as np; #import numpy

# %%
# arange function
np_arr1=np.arange(1,100,10) # arange return a vector or 1D array with stopValue-1 number of element
# np.arange(startValue,stopValue,steps)
print("Array with Arange method: ",np_arr1)
# Out:
# Array with Arange method:  [ 1 11 21 31 41 51 61 71 81 91]

# %%
# linspace function or method
np_arr2=np.linspace(100,150,2)
print("Array with linspace method:",np_arr2)
# Out:
# Array with linspace method: [100.         101.72413793 103.44827586 105.17241379 106.89655172
#  108.62068966 110.34482759 112.06896552 113.79310345 115.51724138
#  117.24137931 118.96551724 120.68965517 122.4137931  124.13793103
#  125.86206897 127.5862069  129.31034483 131.03448276 132.75862069
#  134.48275862 136.20689655 137.93103448 139.65517241 141.37931034
#  143.10344828 144.82758621 146.55172414 148.27586207 150.        ]
