# %% [markdown]
#         Question:
#             Create a one-dimensional array in a program, print its type and dimension as well and then also show a list in your program.

# %%
import numpy as np; # import numpy and create alias for easy to use

# %% [markdown]
# Array Part

# %%
oneDArray=np.array([1,2,3,4,5,6,7])
print(f"Array: {oneDArray}")
print(f"Type of Array: {type(oneDArray)}")
print(f"Dimension of Array: {oneDArray.ndim}")
# Out:
# Array: [1 2 3 4 5 6 7]
# Type of Array: <class 'numpy.ndarray'>
# Dimension of Array: 1

# %% [markdown]
# List Part

# %%
list=[1,2,3,4,5,6,7]
print(f"List:{list}")
print(f"Type of list: {type(list)}")
# print(f"Dimension of list: {list.ndim}") # it is a list , so does n't find the dimension
# Out:
# List:[1, 2, 3, 4, 5, 6, 7]
# Type of list: <class 'list'>

# %% [markdown]
# Question:
#         Create a 2D array in your program and then print its type and dimensions.

# %%
towDArray=np.array([[1,2,3,4,5,6]])
print(f"Array: {towDArray}")
print(f"Type of Array: {type(towDArray)}")
print(f"Dimension of Array: {towDArray.ndim}")
# Out:
# Array: [[1 2 3 4 5 6]]
# Type of Array: <class 'numpy.ndarray'>
# Dimension of Array: 2
