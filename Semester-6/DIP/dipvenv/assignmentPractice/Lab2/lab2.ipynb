# %% [markdown]
# Lab2: Assignment

# %% [markdown]
# Question:
#         Create a 2 D matrix of ones then also show its shape, size and data type and then change the datatype from float to integer.

# %%
import numpy as np; # import numpy as set alias for easy to use

# %% [markdown]
# Method-1: To create 2D matrix

# %%
twoDMatrix=np.array([[1.,1,1,1],[1,1,1,1]]) # if there only one element has float then the  matrix datatype  will be float datatype not int 
print(f"2D Matrix is: {twoDMatrix}")
print(f"Shap of 2d Matrix:{twoDMatrix.shape}") # shap method return the number of row and column in matrix like this form (rows,column)
print(f"Size of 2d Matrix:{twoDMatrix.size}") # size method return the total number of element inside the matrix
print(f"Data Type of 2d Matrix:{twoDMatrix.dtype}") # dtype method return the data type of the matrix 
twoDMatrix.dtype=int # here we done typeCasting to change the data type from flaot to int
print(f"Change the Data Type of 2d Matrix:{twoDMatrix.dtype}")
# Out:
# 2D Matrix is: [[1. 1. 1. 1.]
#  [1. 1. 1. 1.]]
# Shap of 2d Matrix:(2, 4)
# Size of 2d Matrix:8
# Data Type of 2d Matrix:float64
# Change the Data Type of 2d Matrix:int64

# %% [markdown]
# Method-2: Create 2D matrix

# %%
# towDMatix1=np.ones((2,3)) # Here we use two methods ones and shap. shap (2,3) this return 2 by 3 matrix and ones method insert 1 as element of the 2 by 3 matrix and by default it return float as datatype
towDMatix1=np.ones((2,3),dtype=int) # second argument change the dafualt datatype float to int
print(f"2D Matrix is: {towDMatix1}")
print(f"Shap of 2d Matrix:{towDMatix1.shape}") # shap method return the number of row and column in matrix like this form (rows,column)
print(f"Size of 2d Matrix:{towDMatix1.size}") # size method return the total number of element inside the matrix
print(f"Data Type of 2d Matrix:{towDMatix1.dtype}") # dtype method return the data type of the matrix
# Out:
# 2D Matrix is: [[1 1 1]
#  [1 1 1]]
# Shap of 2d Matrix:(2, 3)
# Size of 2d Matrix:6
# Data Type of 2d Matrix:int64

# %% [markdown]
# Question:
#         Modify the above example no.1 (Lab#2) and create two matrices M1 and M2. M1 should have the string data type while M2 should have the bool datatype. M1 should be created by using the zeros function instead of ones.

# %%
towDMatix2=np.zeros((2,3),dtype=str) # second argument change the dafualt datatype float to str
print(f"2D Matrix is: {towDMatix2}") # values are empty string because we use zeros func and this equal to ""
print(f"Shap of 2d Matrix:{towDMatix2.shape}") # shap method return the number of row and column in matrix like this form (rows,column)
print(f"Size of 2d Matrix:{towDMatix2.size}") # size method return the total number of element inside the matrix
print(f"Data Type of 2d Matrix:{towDMatix2.dtype}") # dtype method return the data type of the matrix
# Out:
# 2D Matrix is: [['' '' '']
#  ['' '' '']]
# Shap of 2d Matrix:(2, 3)
# Size of 2d Matrix:6
# Data Type of 2d Matrix:<U1

# %%
towDMatix3=np.ones((2,3),dtype=bool) # second argument change the dafualt datatype float to int
print(f"2D Matrix is: {towDMatix3}")
print(f"Shap of 2d Matrix:{towDMatix3.shape}") # shap method return the number of row and column in matrix like this form (rows,column)
print(f"Size of 2d Matrix:{towDMatix3.size}") # size method return the total number of element inside the matrix
print(f"Data Type of 2d Matrix:{towDMatix3.dtype}") # dtype method return the data type of the matrix
# Out:
# 2D Matrix is: [[ True  True  True]
#  [ True  True  True]]
# Shap of 2d Matrix:(2, 3)
# Size of 2d Matrix:6
# Data Type of 2d Matrix:bool

# %%
towDMatix4=np.random.random((4,4)) #  Here we use two methods ones and shap. shap (4,4) this return 4 by 4 matrix and ones method insert 1 as element of the 4 by 4 matrix and by default it return float as datatype second argument change the dafualt datatype float to int
print(f"4D Matrix is: {towDMatix4}")
print(f"Shap of 4D Matrix:{towDMatix4.shape}") # shap method return the number of row and column in matrix like this form (rows,column)
print(f"Size of 4D Matrix:{towDMatix4.size}") # size method return the total number of element inside the matrix
print(f"Data Type of 4D Matrix:{towDMatix4.dtype}") # dtype method return the data type of the matrix
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 towDMatix4=np.random.random((4,4),dtype=int) #  Here we use two methods ones and shap. shap (4,4) this return 4 by 4 matrix and ones method insert 1 as element of the 4 by 4 matrix and by default it return float as datatype second argument change the dafualt datatype float to int
#       2 print(f"4D Matrix is: {towDMatix4}")
#       3 print(f"Shap of 4D Matrix:{towDMatix4.shape}") # shap method return the number of row and column in matrix like this form (rows,column)
#
# File numpy\\random\\mtrand.pyx:443, in numpy.random.mtrand.RandomState.random()
#
# TypeError: random() got an unexpected keyword argument 'dtype'
