# %%
import numpy as np;
from sklearn.linear_model import LinearRegression;


X=np.array([[1],[2],[3],[4]])
y=np.array([2,4,6,8])

model=LinearRegression()
model.fit(X,y)
predict_val=np.array([[8]])
predict=model.predict(predict_val)
print("Predicted value:",predict[0])
# Out:
# Predicted value: [16.]
